# %% [markdown]
# # py1：输入与输出
#
# 本 notebook 由 `py1.py` 转换而来，代码保持原脚本的学习顺序，并补充了中文 Markdown 注解。
#
# ## 学习目标
# - 使用 print() 输出文本
# - 使用 input() 读取用户输入
# - 用 f-string 把变量嵌入字符串
#
# > 运行建议：按顺序逐个执行代码单元。遇到 `input()` 或依赖命令行参数的示例时，notebook 的交互方式会和直接运行 `.py` 略有不同。

# %% [markdown]
# ## 输出字符串
#
# print() 会把内容显示到屏幕上，是最基础的调试和交互方式。

# %%
#输出字符串
print('hello, world')

# %% [markdown]
# ## 输入字符串
#
# input() 会暂停程序并等待键盘输入；在 notebook 中运行这一格时，也会出现输入提示。

# %%
#输入字符串
name = input('请输入你的名字：')
print(f'你好，{name}！')
